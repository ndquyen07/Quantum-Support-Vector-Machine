# %%
#!/usr/bin/env python3
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))

# %%
from qiskit.circuit.library import TwoLocal, RealAmplitudes, EfficientSU2

ansatz = EfficientSU2(num_qubits= 4 , entanglement='linear', reps=1)
ansatz.decompose().draw('mpl')

# %%
# update last change
import importlib
import src.ansatz
importlib.reload(src.ansatz)
# Out:
# <module 'src.ansatz' from 'd:\\QuantumComputing\\SVQSVM\\src\\ansatz.py'>

# %%
from src.ansatz import Ansatz

ansatz1 = Ansatz.TwoLocal(depth=1, num_qubits=4)
ansatz1.draw('mpl')

# %%
ansatz2 = Ansatz.RealAmplitudes(depth=1, num_qubits=4)
ansatz2.draw('mpl')

# %%
ansatz3 = Ansatz.EfficientSU2(depth=1, num_qubits=4)
ansatz3.draw('mpl')

# %%
ansatz4 = Ansatz.custom_ansatz1(num_qubits=4, depth=1)
ansatz4.draw('mpl')

# %%
ansatz4 = Ansatz.custom_ansatz2(num_qubits=4, depth=1)
ansatz4.draw('mpl')
