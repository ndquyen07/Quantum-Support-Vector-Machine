# %% [markdown]
# ## 1. Load Data

# %%
import numpy as np

# Load npz
data = np.load("../data/iris_4features_data.npz")

X_train = data['X_train']
y_train = data['y_train']
X_val = data['X_val']
y_val = data['y_val']
X_test = data['X_test']
y_test = data['y_test']

print(f"Training X shape: {X_train.shape}, y shape: {y_train.shape}")
print(f"Validation X shape: {X_val.shape}, y shape: {y_val.shape}")
print(f"Testing X shape: {X_test.shape}, y shape: {y_test.shape}")
# Out:
# Training X shape: (90, 4), y shape: (90,)
# Validation X shape: (30, 4), y shape: (30,)
# Testing X shape: (30, 4), y shape: (30,)

# %% [markdown]
# ## 2. Traiable Quantum Feature Map

# %%
#!/usr/bin/env python3
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))

# %%
from src.feature_map import TrainableQuantumFeatureMap as TQFM1
from qiskit_algorithms.optimizers import COBYLA, ADAM


depth = 1
optimizer = ADAM(maxiter=1000, lr=0.1, tol=1e-3)


# Train the feature map
tqfm1 = TQFM1(depth=depth, type_ansatz="RealAmplitudes")
tqfm1.fit(X_train, y_train, optimizer=optimizer)
# Out:
# Number of qubits: 4, Number of classes: 3
# Using AerSimulator for accelerated statevector computation

# %%
# draw 3 loss curves in one plot
import matplotlib.pyplot as plt
plt.plot(tqfm1.loss_history, label='RealAmplitudes')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

# %%
from src.feature_map import TrainableQuantumFeatureMap as TQFM1
from qiskit_algorithms.optimizers import COBYLA, ADAM


depth = 1
optimizer = COBYLA(maxiter=10000)


# Train the feature map
tqfm2 = TQFM1(depth=depth, type_ansatz="RealAmplitudes")
tqfm2.fit(X_train, y_train, optimizer=optimizer)
# Out:
# Number of qubits: 4, Number of classes: 3
# Using AerSimulator for accelerated statevector computation

# %%
# draw 3 loss curves in one plot
import matplotlib.pyplot as plt
plt.plot(tqfm2.loss_history, label='RealAmplitudes')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

# %%
print(tqfm1.optimal_value)
# Out:
# None

# %%
from src.feature_map2 import TrainableQuantumFeatureMap as TQFM3
from qiskit_algorithms.optimizers import COBYLA, ADAM


depth = 2
optimizer = COBYLA(maxiter=10000)


# Train the feature map
tqfm3 = TQFM3(depth=depth, type_ansatz="EfficientSU2")
tqfm3.fit(X_train, y_train, optimizer=optimizer)
# Out:
# Number of qubits: 4, Number of classes: 3
# Using AerSimulator for accelerated statevector computation

# %%
# draw 3 loss curves in one plot
import matplotlib.pyplot as plt
plt.plot(tqfm3.loss_history, label='EfficientSU2')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

# %%
print(tqfm1.optimal_value)
print(tqfm3.optimal_value)
# Out:
# 0.35427514653790837
# 0.3542751435316446

# %%
from src.feature_map1 import TrainableQuantumFeatureMap as TQFM2
from qiskit_algorithms.optimizers import COBYLA, ADAM


depth = 1
optimizer = COBYLA(maxiter=10000)


# Train the feature map
tqfm2 = TQFM2(depth=depth, type_ansatz="EfficientSU2")
tqfm2.fit(X_train, y_train, optimizer=optimizer)
# Out:
# Number of qubits: 4, Number of classes: 3

# %%
from src.feature_map import TrainableQuantumFeatureMap
from qiskit_algorithms.optimizers import COBYLA,SPSA, ADAM


depth = 1
optimizer = ADAM(maxiter=10000)


# Train the feature map
tqfm1 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm1.fit(X_train, y_train, optimizer=optimizer)

tqfm2 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm2.fit(X_train, y_train, optimizer=optimizer)

tqfm3 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm3.fit(X_train, y_train, optimizer=optimizer)
# Out:
# Number of qubits: 4, Number of classes: 3
# Number of qubits: 4, Number of classes: 3
# Number of qubits: 4, Number of classes: 3

# %%
print(f"tqfm1.optimal_value: {tqfm1.optimal_value}")
print(f"tqfm2.optimal_value: {tqfm2.optimal_value}")
print(f"tqfm3.optimal_value: {tqfm3.optimal_value}")
# Out:
# tqfm1.optimal_value: 0.4300086465525471
# tqfm2.optimal_value: 0.5220406783034139
# tqfm3.optimal_value: 0.4247108057727772

# %%
# draw 3 loss curves in one plot
import matplotlib.pyplot as plt
plt.plot(tqfm1.loss_history, label='TwoLocal')
plt.plot(tqfm2.loss_history, label='RealAmplitudes')
plt.plot(tqfm3.loss_history, label='EfficientSU2')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

# %%
from src.feature_map import TrainableQuantumFeatureMap
from qiskit_algorithms.optimizers import COBYLA,SPSA, ADAM


depth = 1
optimizer = COBYLA(maxiter=10000)


# Train the feature map
tqfm4 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm4.fit(X_train, y_train, optimizer=optimizer)

tqfm5 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm5.fit(X_train, y_train, optimizer=optimizer)

tqfm6 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm6.fit(X_train, y_train, optimizer=optimizer)
# Out:
# Number of qubits: 4, Number of classes: 3
# Number of qubits: 4, Number of classes: 3
# Number of qubits: 4, Number of classes: 3

# %%
# draw 3 loss curves in one plot
import matplotlib.pyplot as plt
plt.plot(tqfm4.loss_history, label='TwoLocal')
plt.plot(tqfm5.loss_history, label='RealAmplitudes')
plt.plot(tqfm6.loss_history, label='EfficientSU2')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

# %%
from src.feature_map import TrainableQuantumFeatureMap
from qiskit_algorithms.optimizers import COBYLA,SPSA, ADAM


depth = 2
optimizer = COBYLA(maxiter=10000)


# Train the feature map
tqfm4 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm4.fit(X_train, y_train, optimizer=optimizer)

tqfm5 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm5.fit(X_train, y_train, optimizer=optimizer)

tqfm6 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm6.fit(X_train, y_train, optimizer=optimizer)
# Out:
# Number of qubits: 4, Number of classes: 3
# Number of qubits: 4, Number of classes: 3
# Number of qubits: 4, Number of classes: 3

# %%
# draw 3 loss curves in one plot
import matplotlib.pyplot as plt
plt.plot(tqfm4.loss_history, label='EfficientSU2')
plt.plot(tqfm5.loss_history, label='EfficientSU2')
plt.plot(tqfm6.loss_history, label='EfficientSU2')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

# %%
from src.feature_map import TrainableQuantumFeatureMap
from qiskit_algorithms.optimizers import COBYLA,SPSA, ADAM


depth = 3
optimizer = COBYLA(maxiter=10000)


# Train the feature map
tqfm7 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm7.fit(X_train, y_train, optimizer=optimizer)

tqfm8 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm8.fit(X_train, y_train, optimizer=optimizer)

tqfm9 = TrainableQuantumFeatureMap(depth=depth, type_ansatz="EfficientSU2")
tqfm9.fit(X_train, y_train, optimizer=optimizer)
# Out:
# Number of qubits: 4, Number of classes: 3
# Number of qubits: 4, Number of classes: 3
# Number of qubits: 4, Number of classes: 3

# %%
# draw 3 loss curves in one plot
import matplotlib.pyplot as plt
plt.plot(tqfm7.loss_history, label='EfficientSU2')
plt.plot(tqfm8.loss_history, label='EfficientSU2')
plt.plot(tqfm9.loss_history, label='EfficientSU2')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

# %%
# draw 3 loss curves in one plot
import matplotlib.pyplot as plt
plt.plot(tqfm4.loss_history, label='EfficientSU2 (depth=1)')
plt.plot(tqfm6.loss_history, label='EfficientSU2 (depth=2)')
plt.plot(tqfm8.loss_history, label='EfficientSU2 (depth=3)')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
